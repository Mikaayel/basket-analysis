# %%
import pandas as pd
import numpy as np
import pyfpgrowth

# %%
df = pd.read_csv('./data/Groceries_dataset.csv');

# %%
df.head()
# Out:
#    Member_number        Date   itemDescription
# 0           1808  21-07-2015    tropical fruit
# 1           2552  05-01-2015        whole milk
# 2           2300  19-09-2015         pip fruit
# 3           1187  12-12-2015  other vegetables
# 4           3037  01-02-2015        whole milk

# %%
unique_items = df['itemDescription'].unique().tolist()

# %%
unique_items
# Out:
# ['tropical fruit',
#  'whole milk',
#  'pip fruit',
#  'other vegetables',
#  'rolls/buns',
#  'pot plants',
#  'citrus fruit',
#  'beef',
#  'frankfurter',
#  'chicken',
#  'butter',
#  'fruit/vegetable juice',
#  'packaged fruit/vegetables',
#  'chocolate',
#  'specialty bar',
#  'butter milk',
#  'bottled water',
#  'yogurt',
#  'sausage',
#  'brown bread',
#  'hamburger meat',
#  'root vegetables',
#  'pork',
#  'pastry',
#  'canned beer',
#  'berries',
#  'coffee',
#  'misc. beverages',
#  'ham',
#  'turkey',
#  'curd cheese',
#  'red/blush wine',
#  'frozen potato products',
#  'flour',
#  'sugar',
#  'frozen meals',
#  'herbs',
#  'soda',
#  'detergent',
#  'grapes',
#  'processed cheese',
#  'fish',
#  'sparkling wine',
#  'newspapers',
#  'curd',
#  'pasta',
#  'popcorn',
#  'finished products',
#  'beverages',
#  'bottled beer',
#  'dessert',
#  'dog food',
#  'specialty chocolate',
#  'condensed milk',
#  'cleaner',
#  'white wine',
#  'meat',
#  'ice cream',
#  'hard cheese',
#  'cream cheese ',
#  'liquor',
#  'pickled vegetables',
#  'liquor (appetizer)',
#  'UHT-milk',
#  'candy',
#  'onions',
#  'hair spray',
#  'photo/film',
#  'domestic eggs',
#  'margarine',
#  'shopping bags',
#  'salt',
#  'oil',
#  'whipped/sour cream',
#  'frozen vegetables',
#  'sliced cheese',
#  'dish cleaner',
#  'baking powder',
#  'specialty cheese',
#  'salty snack',
#  'Instant food products',
#  'pet care',
#  'white bread',
#  'female sanitary products',
#  'cling film/bags',
#  'soap',
#  'frozen chicken',
#  'house keeping products',
#  'spread cheese',
#  'decalcifier',
#  'frozen dessert',
#  'vinegar',
#  'nuts/prunes',
#  'potato products',
#  'frozen fish',
#  'hygiene articles',
#  'artif. sweetener',
#  'light bulbs',
#  'canned vegetables',
#  'chewing gum',
#  'canned fish',
#  'cookware',
#  'semi-finished bread',
#  'cat food',
#  'bathroom cleaner',
#  'prosecco',
#  'liver loaf',
#  'zwieback',
#  'canned fruit',
#  'frozen fruits',
#  'brandy',
#  'baby cosmetics',
#  'spices',
#  'napkins',
#  'waffles',
#  'sauces',
#  'rum',
#  'chocolate marshmallow',
#  'long life bakery product',
#  'bags',
#  'sweet spreads',
#  'soups',
#  'mustard',
#  'specialty fat',
#  'instant coffee',
#  'snack products',
#  'organic sausage',
#  'soft cheese',
#  'mayonnaise',
#  'dental care',
#  'roll products ',
#  'kitchen towels',
#  'flower soil/fertilizer',
#  'cereals',
#  'meat spreads',
#  'dishes',
#  'male cosmetics',
#  'candles',
#  'whisky',
#  'tidbits',
#  'cooking chocolate',
#  'seasonal products',
#  'liqueur',
#  'abrasive cleaner',
#  'syrup',
#  'ketchup',
#  'cream',
#  'skin care',
#  'rubbing alcohol',
#  'nut snack',
#  'cocoa drinks',
#  'softener',
#  'organic products',
#  'cake bar',
#  'honey',
#  'jam',
#  'kitchen utensil',
#  'flower (seeds)',
#  'rice',
#  'tea',
#  'salad dressing',
#  'specialty vegetables',
#  'pudding powder',
#  'ready soups',
#  'make up remover',
#  'toilet cleaner',
#  'preservation products']

# %%
unique_items.index('butter')
# Out:
# 10

# %%
df['itemLookup'] = df['itemDescription'].apply(lambda x: unique_items.index(x))

# %%
df
# Out:
#        Member_number        Date        itemDescription  itemLookup
# 0               1808  21-07-2015         tropical fruit           0
# 1               2552  05-01-2015             whole milk           1
# 2               2300  19-09-2015              pip fruit           2
# 3               1187  12-12-2015       other vegetables           3
# 4               3037  01-02-2015             whole milk           1
# ...              ...         ...                    ...         ...
# 38760           4471  08-10-2014          sliced cheese          75
# 38761           2022  23-02-2014                  candy          64
# 38762           1097  16-04-2014               cake bar         153
# 38763           1510  03-12-2014  fruit/vegetable juice          11
# 38764           1521  26-12-2014               cat food         103
#
# [38765 rows x 4 columns]

# %%
basket = pd.DataFrame(df.groupby(['Member_number', 'Date'], as_index=True).apply(lambda item: item['itemLookup'].tolist()))

# %%
transactions = basket[0].tolist()

# %%
patterns = pyfpgrowth.find_frequent_patterns(transactions, 2)

# %%
rules = pyfpgrowth.generate_association_rules(patterns, 0.7)

# %%
# for key, val in rules.items():
#     for k in key:
#         print(unique_items[k], '--->', unique_items[val[0][0]], val[1])
# Out:
# bags ---> yogurt 0.75
# frankfurter ---> domestic eggs 1.0
# rubbing alcohol ---> domestic eggs 1.0
# domestic eggs ---> frankfurter 1.0
# rubbing alcohol ---> frankfurter 1.0
# soda ---> other vegetables 1.0
# flower soil/fertilizer ---> other vegetables 1.0
# pork ---> curd 2.0
# flower soil/fertilizer ---> curd 2.0
# curd ---> pork 1.3333333333333333
# flower soil/fertilizer ---> pork 1.3333333333333333
# other vegetables ---> curd 2.0
# pork ---> curd 2.0
# flower soil/fertilizer ---> curd 2.0
# other vegetables ---> pork 2.0
# curd ---> pork 2.0
# flower soil/fertilizer ---> pork 2.0
# pork ---> other vegetables 1.0
# curd ---> other vegetables 1.0
# flower soil/fertilizer ---> other vegetables 1.0
# frozen vegetables ---> canned beer 1.0
# cookware ---> canned beer 1.0
# whole milk ---> canned beer 1.0
# bottled water ---> canned beer 1.0
# cookware ---> canned beer 1.0
# whole milk ---> bottled water 1.0
# canned beer ---> bottled water 1.0
# cookware ---> bottled water 1.0
# canned beer ---> bottled water 0.75
# cookware ---> bottled water 0.75
# other vegetables ---> canned beer 1.0
# cookware ---> canned beer 1.0
# oil ---> whole milk 1.0
# cookware ---> whole milk 1.0
# chicken ---> other vegetables 1.0
# bathroom cleaner ---> other vegetables 1.0
# fruit/vegetable juice ---> other vegetables 1.0
# bathroom cleaner ---> other vegetables 1.0
# chicken ---> fruit/vegetable juice 1.0
# soda ---> fruit/vegetable juice 1.0
# bathroom cleaner ---> fruit/vegetable juice 1.0
# fruit/vegetable juice ---> chicken 1.0
# soda ---> chicken 1.0
# bathroom cleaner ---> chicken 1.0
# other vegetables ---> chicken 1.0
# bathroom cleaner ---> chicken 1.0
# other vegetables ---> fruit/vegetable juice 1.0
# chicken ---> fruit/vegetable juice 1.0
# bathroom cleaner ---> fruit/vegetable juice 1.0
# other vegetables ---> chicken 1.0
# fruit/vegetable juice ---> chicken 1.0
# bathroom cleaner ---> chicken 1.0
# fruit/vegetable juice ---> other vegetables 1.0
# prosecco ---> other vegetables 1.0
# ice cream ---> other vegetables 1.5
# prosecco ---> other vegetables 1.5
# prosecco ---> whole milk 1.0
# waffles ---> whole milk 1.0
# other vegetables ---> whole milk 1.0
# sausage ---> whole milk 1.0
# prosecco ---> whole milk 1.0
# other vegetables ---> whole milk 1.0
# prosecco ---> whole milk 1.0
# waffles ---> whole milk 1.0
# sausage ---> whole milk 1.0
# prosecco ---> whole milk 1.0
# waffles ---> whole milk 1.0
# whole milk ---> other vegetables 1.0
# prosecco ---> other vegetables 1.0
# whole milk ---> other vegetables 1.0
# sausage ---> other vegetables 1.0
# prosecco ---> other vegetables 1.0
# whole milk ---> other vegetables 1.0
# prosecco ---> other vegetables 1.0
# waffles ---> other vegetables 1.0
# whole milk ---> sausage 1.0
# other vegetables ---> sausage 1.0
# prosecco ---> sausage 1.0
# whole milk ---> waffles 1.0
# other vegetables ---> waffles 1.0
# sausage ---> waffles 1.0
# prosecco ---> waffles 1.0
# whole milk ---> sausage 1.0
# other vegetables ---> sausage 1.0
# prosecco ---> sausage 1.0
# waffles ---> sausage 1.0
# whole milk ---> other vegetables 1.0
# sausage ---> other vegetables 1.0
# prosecco ---> other vegetables 1.0
# waffles ---> other vegetables 1.0
# other vegetables ---> whole milk 1.0
# sausage ---> whole milk 1.0
# prosecco ---> whole milk 1.0
# waffles ---> whole milk 1.0
# beverages ---> other vegetables 1.0
# prosecco ---> other vegetables 1.0
# soda ---> other vegetables 1.0
# prosecco ---> other vegetables 1.0
# domestic eggs ---> other vegetables 1.0
# skin care ---> other vegetables 1.0
# tropical fruit ---> whole milk 1.0
# soap ---> whole milk 1.0
# whole milk ---> tropical fruit 1.0
# soap ---> tropical fruit 1.0
# tropical fruit ---> whole milk 1.0
# syrup ---> whole milk 1.0
# sausage ---> whole milk 1.3333333333333333
# canned fruit ---> whole milk 1.3333333333333333
# canned beer ---> other vegetables 1.0
# nut snack ---> other vegetables 1.0
# other vegetables ---> yogurt 1.0
# newspapers ---> yogurt 1.0
# nut snack ---> yogurt 1.0
# yogurt ---> other vegetables 1.0
# newspapers ---> other vegetables 1.0
# nut snack ---> other vegetables 1.0
# cream cheese  ---> root vegetables 1.0
# nut snack ---> root vegetables 1.0
# curd ---> root vegetables 1.0
# nut snack ---> root vegetables 1.0
# root vegetables ---> cream cheese  1.0
# curd ---> cream cheese  1.0
# nut snack ---> cream cheese  1.0
# root vegetables ---> curd 1.0
# cream cheese  ---> curd 1.0
# nut snack ---> curd 1.0
# curd ---> root vegetables 1.0
# cream cheese  ---> root vegetables 1.0
# nut snack ---> root vegetables 1.0
# other vegetables ---> yogurt 1.0
# nut snack ---> yogurt 1.0
# yogurt ---> other vegetables 0.75
# nut snack ---> other vegetables 0.75
# other vegetables ---> yogurt 1.0
# soda ---> yogurt 1.0
# nut snack ---> yogurt 1.0
# root vegetables ---> soda 1.0
# abrasive cleaner ---> soda 1.0
# whipped/sour cream ---> root vegetables 1.0
# abrasive cleaner ---> root vegetables 1.0
# soda ---> root vegetables 1.0
# abrasive cleaner ---> root vegetables 1.0
# tropical fruit ---> other vegetables 1.0
# organic sausage ---> other vegetables 1.0
# frankfurter ---> other vegetables 1.0
# potato products ---> other vegetables 1.0
# frozen vegetables ---> other vegetables 1.0
# snack products ---> other vegetables 1.0
# pork ---> other vegetables 1.0
# snack products ---> other vegetables 1.0
# frozen vegetables ---> cat food 1.0
# tea ---> cat food 1.0
# cat food ---> frozen vegetables 1.0
# tea ---> frozen vegetables 1.0
# chicken ---> other vegetables 1.0
# fish ---> other vegetables 1.0
# fish ---> other vegetables 1.0
# cream cheese  ---> other vegetables 1.0
# fish ---> other vegetables 1.0
# UHT-milk ---> other vegetables 1.0
# fish ---> other vegetables 1.0
# hard cheese ---> other vegetables 1.0
# chicken ---> other vegetables 1.0
# fish ---> other vegetables 1.0
# cream cheese  ---> other vegetables 1.0
# chicken ---> other vegetables 1.0
# fish ---> other vegetables 1.0
# UHT-milk ---> other vegetables 1.0
# chicken ---> other vegetables 1.0
# cream cheese  ---> other vegetables 1.0
# UHT-milk ---> other vegetables 1.0
# chicken ---> other vegetables 1.0
# fish ---> other vegetables 1.0
# hard cheese ---> other vegetables 1.0
# chicken ---> other vegetables 1.0
# hard cheese ---> other vegetables 1.0
# cream cheese  ---> other vegetables 1.0
# other vegetables ---> hard cheese 1.0
# chicken ---> hard cheese 1.0
# fish ---> hard cheese 1.0
# other vegetables ---> cream cheese  1.0
# chicken ---> cream cheese  1.0
# UHT-milk ---> cream cheese  1.0
# chicken ---> other vegetables 1.0
# fish ---> other vegetables 1.0
# hard cheese ---> other vegetables 1.0
# cream cheese  ---> other vegetables 1.0
# chicken ---> other vegetables 1.0
# fish ---> other vegetables 1.0
# hard cheese ---> other vegetables 1.0
# UHT-milk ---> other vegetables 1.0
# chicken ---> other vegetables 1.0
# fish ---> other vegetables 1.0
# cream cheese  ---> other vegetables 1.0
# UHT-milk ---> other vegetables 1.0
# other vegetables ---> chicken 1.0
# cream cheese  ---> chicken 1.0
# UHT-milk ---> chicken 1.0
# other vegetables ---> hard cheese 1.0
# chicken ---> hard cheese 1.0
# fish ---> hard cheese 1.0
# cream cheese  ---> hard cheese 1.0
# other vegetables ---> hard cheese 1.0
# chicken ---> hard cheese 1.0
# fish ---> hard cheese 1.0
# UHT-milk ---> hard cheese 1.0
# other vegetables ---> fish 1.0
# chicken ---> fish 1.0
# cream cheese  ---> fish 1.0
# UHT-milk ---> fish 1.0
# other vegetables ---> cream cheese  1.0
# chicken ---> cream cheese  1.0
# fish ---> cream cheese  1.0
# hard cheese ---> cream cheese  1.0
# other vegetables ---> fish 1.0
# chicken ---> fish 1.0
# hard cheese ---> fish 1.0
# cream cheese  ---> fish 1.0
# other vegetables ---> UHT-milk 1.0
# chicken ---> UHT-milk 1.0
# fish ---> UHT-milk 1.0
# hard cheese ---> UHT-milk 1.0
# cream cheese  ---> UHT-milk 1.0
# other vegetables ---> cream cheese  1.0
# chicken ---> cream cheese  1.0
# fish ---> cream cheese  1.0
# hard cheese ---> cream cheese  1.0
# UHT-milk ---> cream cheese  1.0
# other vegetables ---> hard cheese 1.0
# chicken ---> hard cheese 1.0
# fish ---> hard cheese 1.0
# cream cheese  ---> hard cheese 1.0
# UHT-milk ---> hard cheese 1.0
# chicken ---> other vegetables 1.0
# fish ---> other vegetables 1.0
# hard cheese ---> other vegetables 1.0
# cream cheese  ---> other vegetables 1.0
# UHT-milk ---> other vegetables 1.0
# ham ---> frankfurter 1.0
# artif. sweetener ---> frankfurter 1.0
# bottled water ---> soda 1.0
# artif. sweetener ---> soda 1.0
# grapes ---> sausage 1.0
# artif. sweetener ---> sausage 1.0
# misc. beverages ---> sausage 1.0
# artif. sweetener ---> sausage 1.0
# artif. sweetener ---> sausage 1.0
# napkins ---> sausage 1.0
# beef ---> pastry 1.0
# ketchup ---> pastry 1.0
# frankfurter ---> bottled water 1.0
# pastry ---> bottled water 1.0
# ketchup ---> bottled water 1.0
# bottled water ---> soda 1.0
# pastry ---> soda 1.0
# ketchup ---> soda 1.0
# bottled water ---> pastry 1.0
# soda ---> pastry 1.0
# ketchup ---> pastry 1.0
# pastry ---> bottled water 1.0
# soda ---> bottled water 1.0
# ketchup ---> bottled water 1.0
# specialty chocolate ---> rolls/buns 1.0
# dental care ---> rolls/buns 1.0
# onions ---> rolls/buns 1.0
# dental care ---> rolls/buns 1.0
# rolls/buns ---> napkins 0.75
# dental care ---> napkins 0.75
# napkins ---> rolls/buns 1.5
# dental care ---> rolls/buns 1.5
# pip fruit ---> soda 2.0
# dental care ---> soda 2.0
# rolls/buns ---> whole milk 1.0
# sausage ---> whole milk 1.0
# nuts/prunes ---> whole milk 1.0
# rolls/buns ---> whole milk 1.0
# root vegetables ---> whole milk 1.0
# nuts/prunes ---> whole milk 1.0
# sausage ---> whole milk 1.0
# root vegetables ---> whole milk 1.0
# nuts/prunes ---> whole milk 1.0
# whole milk ---> root vegetables 1.0
# rolls/buns ---> root vegetables 1.0
# nuts/prunes ---> root vegetables 1.0
# whole milk ---> rolls/buns 1.0
# sausage ---> rolls/buns 1.0
# nuts/prunes ---> rolls/buns 1.0
# whole milk ---> bottled water 1.0
# rolls/buns ---> bottled water 1.0
# sausage ---> bottled water 1.0
# root vegetables ---> bottled water 1.0
# whole milk ---> root vegetables 1.0
# rolls/buns ---> root vegetables 1.0
# sausage ---> root vegetables 1.0
# nuts/prunes ---> root vegetables 1.0
# whole milk ---> sausage 1.0
# rolls/buns ---> sausage 1.0
# root vegetables ---> sausage 1.0
# nuts/prunes ---> sausage 1.0
# whole milk ---> rolls/buns 1.0
# sausage ---> rolls/buns 1.0
# root vegetables ---> rolls/buns 1.0
# nuts/prunes ---> rolls/buns 1.0
# rolls/buns ---> whole milk 1.0
# sausage ---> whole milk 1.0
# root vegetables ---> whole milk 1.0
# nuts/prunes ---> whole milk 1.0
# root vegetables ---> whole milk 0.75
# nuts/prunes ---> whole milk 0.75
# pip fruit ---> soda 1.0
# jam ---> soda 1.0
# canned beer ---> dessert 1.0
# meat spreads ---> dessert 1.0
# dessert ---> canned beer 1.0
# meat spreads ---> canned beer 1.0
# bottled beer ---> frankfurter 1.0
# male cosmetics ---> frankfurter 1.0
# shopping bags ---> soda 1.0
# spices ---> soda 1.0
# chicken ---> other vegetables 1.0
# spices ---> other vegetables 1.0
# canned beer ---> sausage 1.0
# spices ---> sausage 1.0
# female sanitary products ---> rolls/buns 1.0
# sauces ---> rolls/buns 1.0
# root vegetables ---> rolls/buns 1.0
# female sanitary products ---> rolls/buns 1.0
# yogurt ---> whole milk 1.0
# female sanitary products ---> whole milk 1.0
# pastry ---> soda 1.0
# softener ---> soda 1.0
# sausage ---> soda 1.0
# softener ---> soda 1.0
# vinegar ---> whole milk 1.0
# softener ---> whole milk 1.0
# whole milk ---> softener 1.0
# frankfurter ---> softener 1.0
# vinegar ---> softener 1.0
# whole milk ---> vinegar 1.0
# frankfurter ---> vinegar 1.0
# softener ---> vinegar 1.0
# whole milk ---> frankfurter 1.0
# vinegar ---> frankfurter 1.0
# softener ---> frankfurter 1.0
# frankfurter ---> whole milk 1.0
# vinegar ---> whole milk 1.0
# softener ---> whole milk 1.0
# whole milk ---> root vegetables 1.0
# pip fruit ---> root vegetables 1.0
# softener ---> root vegetables 1.0
# whole milk ---> yogurt 1.0
# root vegetables ---> yogurt 1.0
# softener ---> yogurt 1.0
# pip fruit ---> whole milk 1.0
# root vegetables ---> whole milk 1.0
# softener ---> whole milk 1.0
# whole milk ---> root vegetables 1.0
# yogurt ---> root vegetables 1.0
# softener ---> root vegetables 1.0
# yogurt ---> whole milk 1.0
# root vegetables ---> whole milk 1.0
# softener ---> whole milk 1.0
# other vegetables ---> whole milk 1.0
# rolls/buns ---> whole milk 1.0
# softener ---> whole milk 1.0
# other vegetables ---> whole milk 1.0
# soda ---> whole milk 1.0
# softener ---> whole milk 1.0
# rolls/buns ---> whole milk 1.0
# soda ---> whole milk 1.0
# softener ---> whole milk 1.0
# whole milk ---> sausage 1.0
# other vegetables ---> sausage 1.0
# rolls/buns ---> sausage 1.0
# soda ---> sausage 1.0
# whole milk ---> soda 1.0
# other vegetables ---> soda 1.0
# rolls/buns ---> soda 1.0
# softener ---> soda 1.0
# whole milk ---> rolls/buns 1.0
# other vegetables ---> rolls/buns 1.0
# soda ---> rolls/buns 1.0
# softener ---> rolls/buns 1.0
# whole milk ---> other vegetables 1.0
# rolls/buns ---> other vegetables 1.0
# soda ---> other vegetables 1.0
# softener ---> other vegetables 1.0
# other vegetables ---> whole milk 1.0
# rolls/buns ---> whole milk 1.0
# soda ---> whole milk 1.0
# softener ---> whole milk 1.0
# packaged fruit/vegetables ---> tropical fruit 1.0
# cereals ---> tropical fruit 1.0
# brown bread ---> rolls/buns 1.5
# sauces ---> rolls/buns 1.5
# bottled water ---> soda 1.0
# house keeping products ---> soda 1.0
# house keeping products ---> whole milk 1.5
# semi-finished bread ---> whole milk 1.5
# canned beer ---> whole milk 1.5
# house keeping products ---> whole milk 1.5
# pip fruit ---> whole milk 1.0
# house keeping products ---> whole milk 1.0
# tropical fruit ---> whole milk 1.0
# house keeping products ---> whole milk 1.0
# margarine ---> whole milk 1.0
# house keeping products ---> whole milk 1.0
# domestic eggs ---> whole milk 1.0
# house keeping products ---> whole milk 1.0
# other vegetables ---> whole milk 1.5
# house keeping products ---> whole milk 1.5
# curd cheese ---> whole milk 1.0
# whipped/sour cream ---> whole milk 1.0
# beef ---> whole milk 1.0
# curd cheese ---> whole milk 1.0
# fruit/vegetable juice ---> whole milk 1.0
# popcorn ---> whole milk 1.0
# popcorn ---> rolls/buns 1.0
# ice cream ---> rolls/buns 1.0
# popcorn ---> pork 1.0
# oil ---> pork 1.0
# hamburger meat ---> other vegetables 0.75
# popcorn ---> other vegetables 0.75
# pip fruit ---> whole milk 1.0
# soda ---> whole milk 1.0
# soda ---> whole milk 1.0
# soda ---> whole milk 1.0
# soda ---> whole milk 1.0
# popcorn ---> whole milk 1.0
# pip fruit ---> popcorn 1.0
# rolls/buns ---> popcorn 1.0
# bottled water ---> popcorn 1.0
# pip fruit ---> bottled water 1.0
# rolls/buns ---> bottled water 1.0
# popcorn ---> bottled water 1.0
# pip fruit ---> rolls/buns 1.0
# bottled water ---> rolls/buns 1.0
# popcorn ---> rolls/buns 1.0
# citrus fruit ---> yogurt 1.0
# soups ---> yogurt 1.0
# frankfurter ---> yogurt 1.0
# soups ---> yogurt 1.0
# tropical fruit ---> yogurt 1.3333333333333333
# soups ---> yogurt 1.3333333333333333
# sweet spreads ---> tropical fruit 1.0
# soups ---> tropical fruit 1.0
# tropical fruit ---> yogurt 1.0
# shopping bags ---> yogurt 1.0
# soups ---> yogurt 1.0
# shopping bags ---> tropical fruit 1.0
# sweet spreads ---> tropical fruit 1.0
# soups ---> tropical fruit 1.0
# tropical fruit ---> sweet spreads 1.0
# yogurt ---> sweet spreads 1.0
# soups ---> sweet spreads 1.0
# tropical fruit ---> yogurt 1.0
# sweet spreads ---> yogurt 1.0
# soups ---> yogurt 1.0
# yogurt ---> tropical fruit 1.0
# sweet spreads ---> tropical fruit 1.0
# soups ---> tropical fruit 1.0
# yogurt ---> tropical fruit 1.0
# shopping bags ---> tropical fruit 1.0
# soups ---> tropical fruit 1.0
# tropical fruit ---> sweet spreads 1.0
# yogurt ---> sweet spreads 1.0
# shopping bags ---> sweet spreads 1.0
# soups ---> sweet spreads 1.0
# tropical fruit ---> yogurt 1.0
# shopping bags ---> yogurt 1.0
# sweet spreads ---> yogurt 1.0
# soups ---> yogurt 1.0
# yogurt ---> tropical fruit 1.0
# shopping bags ---> tropical fruit 1.0
# sweet spreads ---> tropical fruit 1.0
# soups ---> tropical fruit 1.0
# butter milk ---> rolls/buns 1.0
# rice ---> rolls/buns 1.0
# hamburger meat ---> whole milk 1.0
# liver loaf ---> whole milk 1.0
# shopping bags ---> rolls/buns 2.0
# liver loaf ---> rolls/buns 2.0
# whipped/sour cream ---> whole milk 1.0
# liver loaf ---> whole milk 1.0
# sausage ---> whole milk 1.0
# liver loaf ---> whole milk 1.0
# whole milk ---> white bread 1.0
# sausage ---> white bread 1.0
# liver loaf ---> white bread 1.0
# whole milk ---> sausage 1.0
# white bread ---> sausage 1.0
# liver loaf ---> sausage 1.0
# sausage ---> whole milk 1.0
# white bread ---> whole milk 1.0
# liver loaf ---> whole milk 1.0
# liver loaf ---> rolls/buns 1.5
# flower (seeds) ---> rolls/buns 1.5
# frankfurter ---> condensed milk 1.0
# liver loaf ---> condensed milk 1.0
# pip fruit ---> rolls/buns 1.0
# root vegetables ---> rolls/buns 1.0
# liver loaf ---> rolls/buns 1.0
# pip fruit ---> rolls/buns 1.0
# curd ---> rolls/buns 1.0
# liver loaf ---> rolls/buns 1.0
# root vegetables ---> pip fruit 1.0
# curd ---> pip fruit 1.0
# liver loaf ---> pip fruit 1.0
# rolls/buns ---> pip fruit 1.0
# root vegetables ---> pip fruit 1.0
# liver loaf ---> pip fruit 1.0
# pip fruit ---> liver loaf 1.0
# rolls/buns ---> liver loaf 1.0
# root vegetables ---> liver loaf 1.0
# curd ---> liver loaf 1.0
# pip fruit ---> curd 1.0
# rolls/buns ---> curd 1.0
# root vegetables ---> curd 1.0
# liver loaf ---> curd 1.0
# pip fruit ---> rolls/buns 1.0
# root vegetables ---> rolls/buns 1.0
# curd ---> rolls/buns 1.0
# liver loaf ---> rolls/buns 1.0
# rolls/buns ---> pip fruit 1.0
# root vegetables ---> pip fruit 1.0
# curd ---> pip fruit 1.0
# liver loaf ---> pip fruit 1.0
# whole milk ---> rolls/buns 1.0
# other vegetables ---> rolls/buns 1.0
# liver loaf ---> rolls/buns 1.0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-13-0200dd21b675> in <module>
#       1 for key, val in rules.items():
#       2     for k in key:
# ----> 3         print(unique_items[k], '--->', unique_items[val[0][0]], val[1])
#
# IndexError: tuple index out of range

# %%
src_dest_wght = {}

for key, val in rules.items():
    if len(key) > 1:
        for k in key:
            if (unique_items[k], unique_items[val[0][0]]) in src_dest_wght:
                print('yes')
                old_val = src_dest_wght[(unique_items[k], unique_items[val[0][0]])]
                src_dest_wght[(unique_items[k], unique_items[val[0][0]])] = old_val if old_val > round(val[1], 2) else round(val[1], 2)
            else:
                print('no')
                src_dest_wght[(unique_items[k], unique_items[val[0][0]])] = round(val[1], 2)
    else:
        print('new')
        src_dest_wght[(unique_items[k], unique_items[val[0][0]])] = round(val[1], 2)

# %%
src_dest_wght

# %%
item_count = df.groupby(by = ['itemDescription']).size().reset_index(name = 'support_count')
item_supp = dict(zip(item_count['itemDescription'], item_count['support_count']))

# %%
item_count

# %%
item_supp

# %%
import matplotlib.pyplot as plt
import networkx as nx

# %%
plt.figure(figsize =(16, 7)) 

# Define a directed graph
G = nx.DiGraph()

# Add all the item nodes
for key in item_supp.keys():
    G.add_node(key)

# Set support_count attribute for all the nodes
for i in list(G.nodes()): 
    G.nodes[i]['support_count'] = item_supp[i]
     
# Size of node is a list of support_count
node_size = [nx.get_node_attributes(G, 'support_count')[v] ** 5.5 for v in G] 
    
# Add edges to the graph vased on the rules
for key, val in src_dest_wght.items():
    G.add_edge(key[0], key[1], weight = val)

# Node colour is a list of degrees of nodes 
node_color = [G.degree(v) for v in G] 

# Segregate edges based on the support_threshold value of 0.7
elarge = [(u, v) for (u, v, d) in G.edges(data=True) if d['weight'] > 0.7]
esmall = [(u, v) for (u, v, d) in G.edges(data=True) if d['weight'] <= 0.7]

# Width of edge is a list of weight of edges
elarge_width = [5 * G[u][v]['weight'] for u, v in G.edges()] 
esmall_width = [3 * G[u][v]['weight'] for u, v in G.edges()] 

# Define the graph layout
pos = nx.circular_layout(G)    

# Draw small edges with support_count <= 0.7
nx.draw_networkx(G, pos, edgelist = esmall, node_size = node_size, node_color = node_color, alpha = 0.7, 
                 with_labels = True, width = esmall_width, edge_color ='g', cmap = plt.cm.Blues, 
                 connectionstyle='arc3, rad = 0.1')

# Draw large edges with support_count > 0.7
nx.draw_networkx(G, pos, edgelist = elarge, node_size = node_size, node_color = node_color, alpha = 0.7, 
                 with_labels = True, width = elarge_width, edge_color ='r', cmap = plt.cm.Blues, 
                 connectionstyle='arc3, rad = 0.2')  

# Display edge weights
labels = nx.get_edge_attributes(G,'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels=labels, label_pos=0.3, font_size=10)

plt.axis('off') 
plt.tight_layout();
